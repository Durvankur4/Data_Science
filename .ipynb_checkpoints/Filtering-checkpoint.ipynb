# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("datasets/laptop_price.csv", encoding="latin1")
df.head(3)
# df[df["Company"] == "Apple"].value_counts("Company")
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
#
#                      ScreenResolution                         Cpu  Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz  8GB
# 1                            1440x900        Intel Core i5 1.8GHz  8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz  8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
#
#    Price_euros
# 0      1339.69
# 1       898.94
# 2       575.00

# %%
# df[df["Company"] != "HP"].value_counts("Company")
# df[df["Price_euros"] >= 1300]

# %%
# df["Affordability"] = np.where(df["Price_euros"]>2000,"carro","barato")
# df["Affordability"].value_counts("Affordability").round(2)

# %%
choices = [
    df["Inches"] > 16,
    (df["Inches"] > 14) & (df["Inches"] <= 16),
    (df["Inches"] > 12) & (df["Inches"] <= 14),
    (df["Inches"] <= 12)
]
values = ["too big","big","small","too small"]

# df["screen_sizes"] = np.select(choices,values,default = "unknown")
# df.value_counts("screen_sizes")
# df[df["screen_sizes"] == "too small"]
# np.where(df["screen_sizes"] == "too small")

# %%
# dup=df.duplicated(["Product","TypeName","Inches"])

# df[dup].sort_values(["Product","TypeName"])

# %% [markdown]
# # DE DUPLICATING

# %%
# df = df.sort_values(["Company","Price_euros"])
# dup = df.duplicated("Company",keep= "first")
# df[~dup]

# %%
# df.drop_duplicates("Company").value_counts("Company")

# %%
# df = df.sort_values(["Company","Inches"])
# df[~df.duplicated(["Company"], keep ="first")]

# %%
df["Company"].unique()
# Out:
# <StringArray>
# [     'Acer',     'Apple',      'Asus',     'Chuwi',      'Dell',   'Fujitsu',
#     'Google',        'HP',    'Huawei',        'LG',    'Lenovo',       'MSI',
#   'Mediacom', 'Microsoft',     'Razer',   'Samsung',   'Toshiba',      'Vero',
#     'Xiaomi']
# Length: 19, dtype: str
