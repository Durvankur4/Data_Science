# %%
import pandas as pd

# %%
df =  pd.read_csv("datasets/gdp.csv", encoding = "latin")
# df = df[["country","year","gdppc"]]

# %%
# df.pivot(index= "year",columns="country",values="gdppc")
# df.pivot(index="country",columns="year",values = "gdppc")

# %%
df_1 = pd.read_excel("datasets/supermarket_sales.xlsx")
# df_1.pivot_table(index = "Gender",aggfunc= "sum",numeric_only=True)
# df_1.pivot_table(index = "Gender",values=["Quantity","Rating"],aggfunc= "sum",numeric_only=True)
df_1.pivot_table(index = "Gender",columns= "Product line",values=["Total"],aggfunc= "sum",numeric_only=True)
# Out:
#                               Total                                         \
# Product line Electronic accessories Fashion accessories Food and beverages
# Gender
# Female                   27102.0225           30437.400         33170.9175
# Male                     27235.5090           23868.495         22973.9265
#
#
# Product line Health and beauty Home and lifestyle Sports and travel
# Gender
# Female              18560.9865         30036.8775        28574.7210
# Male                30632.7525         23825.0355        26548.1055
