# %% [markdown]
# # .LOC[]

# %%
import numpy as np
import pandas as pd
df = pd.read_csv("datasets/players_20.csv")
df.set_index("short_name", inplace = True)

# %%
df = df[[ "long_name","age","dob","height_cm","weight_kg","nationality","club"] ]
df.head()
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
#
#                    height_cm  weight_kg nationality                 club
# short_name
# L. Messi                 170         72   Argentina         FC Barcelona
# Cristiano Ronaldo        187         83    Portugal             Juventus
# Neymar Jr                175         68      Brazil  Paris Saint-Germain
# J. Oblak                 188         87    Slovenia      Atlético Madrid
# E. Hazard                175         74     Belgium          Real Madrid

# %%
# # df.loc["L. Messi","weight_kg"]
# df.loc[:,"weight_kg"]
# df.loc["L. Messi","age":"nationality"]

# %%
col = ["long_name","age","dob","height_cm","weight_kg","nationality"]
df.loc[(df["height_cm"]>180) &( df["nationality"] == "Portugal"),col]
# Out:
#                                              long_name  age         dob  \
# short_name
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# A. Lopes                                 Anthony Lopes   28  1990-10-01
# João Cancelo                 João Pedro Cavaco Cancelo   25  1994-05-27
# Pepe                      Képler Laveran Lima Ferreira   36  1983-02-26
# William Carvalho             William Silva de Carvalho   27  1992-04-07
# ...                                                ...  ...         ...
# João Pereira                João Duarte Vieira Pereira   29  1990-05-10
# Rúben Fonseca             Rúben Miguel Valente Fonseca   19  2000-02-24
# Filipe Ferreira                Filipe Ferreira Marques   21  1998-02-25
# Wilson Carvalho       Wilson Roberto Bento De Carvalho   25  1993-07-04
# Alexandre Pimenta             A. Pimenta Flora Pimenta   20  1999-03-02
#
#                    height_cm  weight_kg nationality
# short_name
# ...

# %% [markdown]
# # .iloc[]

# %%
# df.iloc[0,:]

# %%
# df.iloc[:,1]

# %% [markdown]
# # Drop Sample

# %%
df.drop("L. Messi",axis = 0)
# df.sample(random_state = 99,frac = 2,replace = True)
# Out:
#                                              long_name  age         dob  \
# short_name
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
# K. De Bruyne                           Kevin De Bruyne   28  1991-06-28
# ...                                                ...  ...         ...
# Shao Shuai                                          邵帅   22  1997-03-10
# Xiao Mingjie                              Mingjie Xiao   22  1997-01-01
# Zhang Wei                                           张威   19  2000-05-16
# Wang Haijian                                       汪海健   18  2000-08-02
# Pan Ximing                                         潘喜明   26  1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# ...

# %% [markdown]
# # Querry

# %%
import numpy as np
import pandas as pd
df = pd.read_csv("datasets/players_20.csv")
df.set_index("short_name", inplace = True)
df.query("age>34")
df[df["age"]>34]
# Out:
#                  sofifa_id                                         player_url  \
# short_name
# Z. Ibrahimović       41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# Pepe                120533  https://sofifa.com/player/120533/kepler-lavera...
# G. Buffon             1179  https://sofifa.com/player/1179/gianluigi-buffo...
# Casillas              5479  https://sofifa.com/player/5479/iker-casillas-f...
# F. Quagliarella     159261  https://sofifa.com/player/159261/fabio-quaglia...
# ...                    ...                                                ...
# N. Hunt             138083  https://sofifa.com/player/138083/nicky-hunt/20...
# K. Ogi              232539  https://sofifa.com/player/232539/kota-ogi/20/1...
# J. McCombe           11430  https://sofifa.com/player/11430/jamie-mccombe/...
# G. Maley            245558  https://sofifa.com/player/245558/gary-maley/20...
# Zhou Ting           182461  https://sofifa.com/player/182461/ting-zhou/20/...
#
# ...
